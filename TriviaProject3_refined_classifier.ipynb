# %%
#Libraries
import pandas as pd
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Section 1: Clean and Verify Data

# %%
#Read in Data
triviadata1 = pd.read_csv('C:\\Users\\shyar\\OneDrive\\Bootcamp\\Project3\\JEOPARDY_CSV.csv')

# %%
#check data structure
triviadata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1    Air Date    216930 non-null  object
#  2    Round       216930 non-null  object
#  3    Category    216930 non-null  object
#  4    Value       213296 non-null  object
#  5    Question    216930 non-null  object
#  6    Answer      216927 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 11.6+ MB

# %%
value_counts = triviadata1["Category"].value_counts()
toremove = value_counts[value_counts == 1].index
reduced_trivia = triviadata1[~triviadata1.Category.isin(toremove)]
reduced_trivia
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shyar\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 value_counts = triviadata1["Category"].value_counts()
#       2 toremove = value_counts[value_counts == 1].index
#       3 reduced_trivia = triviadata1[~triviadata1.Category.isin(toremove)]
#
# File c:\Users\shyar\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\shyar\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Category'

# %%
#View Sample of Data
triviadata1.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  12/31/2004  Jeopardy!                          HISTORY  $200
# 1         4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
#preview dates
triviadata1[' Air Date'].value_counts()
# Out:
#  Air Date
# 5/19/1997     62
# 11/13/2007    62
# 11/1/2011     61
# 2/5/1993      61
# 2/15/2000     61
#               ..
# 6/26/2000     30
# 1/27/2012     30
# 9/3/1996      30
# 10/21/1997    16
# 10/18/1989    12
# Name: count, Length: 3640, dtype: int64

# %%
# Remove Leading Spaces from Column Names
triviadata1 =  triviadata1.rename(columns={"Show Number": "Show_Number",
                            " Air Date": "Air_Date",
                            " Round": "Round",
                            " Category": "Category",
                            " Value": "Value",
                            " Question": "Question",
                            " Answer": "Answer"})

# %%
#Convert Air Date to Date Format
triviadata1["Air_Date"] = pd.to_datetime(triviadata1.Air_Date)
triviadata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show_Number  216930 non-null  int64
#  1   Air_Date     216930 non-null  datetime64[ns]
#  2   Round        216930 non-null  object
#  3   Category     216930 non-null  object
#  4   Value        213296 non-null  object
#  5   Question     216930 non-null  object
#  6   Answer       216927 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 11.6+ MB

# %%
value_counts = triviadata1["Category"].value_counts()
toremove = value_counts[value_counts <= 50].index
reduced_trivia = triviadata1[~triviadata1.Category.isin(toremove)]
reduced_trivia
# Out:
#         Show_Number   Air_Date             Round        Category    Value  \
# 0              4680 2004-12-31         Jeopardy!         HISTORY    $200
# 5              4680 2004-12-31         Jeopardy!  3-LETTER WORDS    $200
# 6              4680 2004-12-31         Jeopardy!         HISTORY    $400
# 11             4680 2004-12-31         Jeopardy!  3-LETTER WORDS    $400
# 12             4680 2004-12-31         Jeopardy!         HISTORY    $600
# ...             ...        ...               ...             ...      ...
# 216917         4999 2006-05-11  Double Jeopardy!  WORLD CAPITALS  $3,400
# 216922         4999 2006-05-11  Double Jeopardy!      QUOTATIONS  $1,600
# 216923         4999 2006-05-11  Double Jeopardy!  WORLD CAPITALS  $2,000
# 216928         4999 2006-05-11  Double Jeopardy!      QUOTATIONS  $2,000
# 216929         4999 2006-05-11   Final Jeopardy!  HISTORIC NAMES      NaN
#
#                                                  Question  \
# 0       For the last 8 years of his life, Galileo was ...
# 5       In the title of an Aesop fable, this insect sh...
# 6       Built in 312 B.C. to link Rome & the South of ...
# 11      Cows regurgitate this from the first stomach t...
# 12      In 1000 Rajaraja I of the Cholas battled to ta...
# ...                                                   ...
# 216917    Guyanese capital named for a Hanoverian monarch
# 216922  A motto of hers was "in politics, if you want ...
# 216923                         It's on the Suriname River
# 216928  From Ft. Sill, Okla. he made the plea, Arizona...
# 216929  A silent movie title includes the last name of...
#
#                                 Answer
# 0                           Copernicus
# 5                              the ant
# 6                       the Appian Way
# 11                             the cud
# 12               Ceylon (or Sri Lanka)
# ...                                ...
# 216917                      Georgetown
# 216922             (Margaret) Thatcher
# 216923                      Paramaribo
# 216928                        Geronimo
# 216929  Grigori Alexandrovich Potemkin
#
# [42477 rows x 7 columns]

# %%
reduced_trivia["Category"].value_counts()
# Out:
# Category
# BEFORE & AFTER         547
# SCIENCE                519
# LITERATURE             496
# AMERICAN HISTORY       418
# POTPOURRI              401
#                       ...
# AWARDS & HONORS         51
# HIGHWAYS & BYWAYS       51
# ANCIENT GREECE          51
# HISTORIC PEOPLE         51
# FROM PAGE TO SCREEN     51
# Name: count, Length: 332, dtype: int64

# %%
# Preview Categories
#pd.set_option("display.max_rows", None)
reduced_trivia["Category"].value_counts()
# Out:
# Category
# BEFORE & AFTER         547
# SCIENCE                519
# LITERATURE             496
# AMERICAN HISTORY       418
# POTPOURRI              401
#                       ...
# AWARDS & HONORS         51
# HIGHWAYS & BYWAYS       51
# ANCIENT GREECE          51
# HISTORIC PEOPLE         51
# FROM PAGE TO SCREEN     51
# Name: count, Length: 332, dtype: int64

# %% [markdown]
# Section 2: Categorize Trivia

# %%
#Remove columns that will not add value
reduced_trivia = reduced_trivia.drop('Show_Number', axis=1)

# %%
#Concatinate 
reduced_trivia["Concat"]  = reduced_trivia["Category"] + " "+ reduced_trivia["Question"] + " " + reduced_trivia["Answer"]
reduced_trivia =  reduced_trivia.dropna()
reduced_trivia.head(20)
# Out:
# C:\Users\shyar\AppData\Local\Temp\ipykernel_16972\529352146.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_trivia["Concat"]  = reduced_trivia["Category"] + " "+ reduced_trivia["Question"] + " " + reduced_trivia["Answer"]
#      Show_Number   Air_Date             Round           Category    Value  \
# 0           4680 2004-12-31         Jeopardy!            HISTORY    $200
# 5           4680 2004-12-31         Jeopardy!     3-LETTER WORDS    $200
# 6           4680 2004-12-31         Jeopardy!            HISTORY    $400
# 11          4680 2004-12-31         Jeopardy!     3-LETTER WORDS    $400
# 12          4680 2004-12-31         Jeopardy!            HISTORY    $600
# 17          4680 2004-12-31         Jeopardy!     3-LETTER WORDS    $600
# 18          4680 2004-12-31         Jeopardy!            HISTORY    $800
# 23          4680 2004-12-31         Jeopardy!     3-LETTER WORDS    $800
# 24          4680 2004-12-31         Jeopardy!            HISTORY  $1,000
# 28          4680 2004-12-31         Jeopardy!     3-LETTER WORDS  $1,000
# 86          5957 2010-07-06  Double Jeopardy!      SCIENCE CLASS    $400
# 91          5957 2010-07-06  Double Jeopardy!  IN THE DICTIONARY    $400
# 92          5957 2010-07-06  Double Jeopardy!      SCIENCE CLASS    $800
# 97          5957 2010-07-06  Double Jeopardy!  IN THE DICTIONARY    $800
# 98          5957 2010-07-06  Double Jeopardy!      SCIENCE CLASS  $1,200
# 103         5957 2010-07-06  Double Jeopardy!  IN THE DICTIONARY  $1,200
# 104         5957 2010-07-06  Double Jeopardy!      SCIENCE CLASS  $5,000
# 109         5957 2010-07-06  Double Jeopardy!  IN THE DICTIONARY  $5,000
# 110         5957 2010-07-06  Double Jeopardy!      SCIENCE CLASS  $2,000
# 115         5957 2010-07-06  Double Jeopardy!  IN THE DICTIONARY  $2,000
#
#                                               Question                 Answer  \
# 0    For the last 8 years of his life, Galileo was ...             Copernicus
# 5    In the title of an Aesop fable, this insect sh...                the ant
# 6    Built in 312 B.C. to link Rome & the South of ...         the Appian Way
# 11   Cows regurgitate this from the first stomach t...                the cud
# 12   In 1000 Rajaraja I of the Cholas battled to ta...  Ceylon (or Sri Lanka)
# 17   A small demon, or a mischievous child (who mig...                    imp
# 18   Karl led the first of these Marxist organizati...      the International
# 23   In geologic time one of these, shorter than an...                    era
# 24   This Asian political party was founded in 1885...     the Congress Party
# 28   A single layer of paper, or to perform one's c...                    ply
# 86       99.95% of the mass of an atom is in this part            the nucleus
# 91   It's the 4-letter name of the pleated skirt wo...                 a kilt
# 92   During this plant process, carbon dioxide & wa...         photosynthesis
# 97   As an adjective, it can mean proper; as a verb...                correct
# 98   The wedge is an adaptation of the simple machi...                  plane
# 103                     Maize is another word for this                   corn
# 104  Of the 6 noble gases on the periodic table, it...                 helium
# 109  This word for someone who walks comes from the...             pedestrian
# 110  Lava & igneous rock are formed from this hot l...                  magma
# 115  Kayak is an example of this, a word that reads...           a palindrome
#
#                                                 Concat
# 0    HISTORY For the last 8 years of his life, Gali...
# 5    3-LETTER WORDS In the title of an Aesop fable,...
# 6    HISTORY Built in 312 B.C. to link Rome & the S...
# 11   3-LETTER WORDS Cows regurgitate this from the ...
# 12   HISTORY In 1000 Rajaraja I of the Cholas battl...
# 17   3-LETTER WORDS A small demon, or a mischievous...
# 18   HISTORY Karl led the first of these Marxist or...
# 23   3-LETTER WORDS In geologic time one of these, ...
# 24   HISTORY This Asian political party was founded...
# 28   3-LETTER WORDS A single layer of paper, or to ...
# 86   SCIENCE CLASS 99.95% of the mass of an atom is...
# 91   IN THE DICTIONARY It's the 4-letter name of th...
# 92   SCIENCE CLASS During this plant process, carbo...
# 97   IN THE DICTIONARY As an adjective, it can mean...
# 98   SCIENCE CLASS The wedge is an adaptation of th...
# 103  IN THE DICTIONARY Maize is another word for th...
# 104  SCIENCE CLASS Of the 6 noble gases on the peri...
# 109  IN THE DICTIONARY This word for someone who wa...
# 110  SCIENCE CLASS Lava & igneous rock are formed f...
# 115  IN THE DICTIONARY Kayak is an example of this,...

# %%
tfidf = TfidfVectorizer(max_df=0.95, min_df=5, stop_words='english')
tfidf
# Out:
# TfidfVectorizer(max_df=0.95, min_df=5, stop_words='english')

# %%
# Transform each row from trivia data to a DTM.
dtm = tfidf.fit_transform(reduced_trivia["Concat"])
# Get the shape of the DTM.
print(dtm.shape)
# Out:
# (41130, 11930)

# %%
#check for NA's
reduced_trivia["Concat"].isna().sum()
# Out:
# 0

# %%
# Initialize the NMF and set the number of topics. 
nmf_model = NMF(n_components=5,random_state=42)
# Fit the model with our DTM data. 
nmf_model.fit(dtm)
# Out:
# NMF(n_components=5, random_state=42)

# %%
# Check the length of the vocabulary 
len(tfidf.get_feature_names_out())
# Out:
# 11930

# %%
# Print the top words for each topic
for index,topic in enumerate(nmf_model.components_):
    print(f'The top words for topic #{index+1}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-33:]])
    print('\n')
# Out:
# The top words for topic #1
# ['sarah', '01', 'jimmy', '09', '12', 'reports', '03', '04', '2009', '02', '10', '2010', '11', '2011', '07', '05', '2008', '2005', '06', '2007', '2006', 'seen', 'crew', 'clue', 'jpg', '_blank', 'target', 'media', 'href', 'http', 'com', 'www', 'archive']
#
#
# The top words for topic #2
# ['old', 'game', 'french', 'describes', 'dictionary', 'phrase', 'precedes', 'small', 'origins', 'synonym', 'adjective', 'comes', 'person', 'type', 'like', 'greek', 'odd', 'used', 'mean', 'meaning', 'phrases', 'foreign', 'means', 'latin', 'term', '13', '12', 'perfect', 'add', '10', 'word', 'words', 'letter']
#
#
# The top words for topic #3
# ['founded', 'bodies', 'national', 'mexico', 'travel', 'area', 'home', 'water', 'university', 'lies', 'york', 'countries', 'miles', 'north', 'sea', 'south', 'named', 'history', 'states', 'islands', 'lake', 'river', 'island', 'new', 'largest', 'cities', 'country', 'geography', 'capitals', 'capital', 'city', 'state', 'world']
#
#
# The top words for topic #4
# ['gem', 'bird', 'romantic', 'game', 'll', 'food', 'song', 'glass', 'groom', 'tiny', 'roman', 'kiss', 'synonym', 'male', 'dessert', 'singer', 'just', 'group', 'fox', 'gourmet', 'liquor', 'baby', 'little', 'terrier', '11', 'adjective', 'face', 'like', 'precedes', 'partner', '10', 'clues', 'crossword']
#
#
# The top words for topic #5
# ['language', 'french', 'country', 'rhyme', 'author', 'women', 'old', 'book', 'english', 'century', 'science', 'known', 'origins', 'title', 'king', 'named', 'president', 'famous', 'names', 'authors', 'wrote', 'people', 'time', 'man', 'john', 'music', 'novel', 'called', 'war', 'literature', 'word', 'history', 'american']

# %%
 # Use the add_topic_labels function to add the topic and topic label to each news summary. 
# Dictionary of  topics and topic label.
topic_labels = {
    1: 'Tech and Media',
    2: 'Literature',
    3: 'Geography',
    4: 'Culture',
    5: 'History'

}

# %%
#KNN clustering
# Define features set
X = app_data.copy()
X.drop("Result", axis=1, inplace=True);g

# %%
# Another type of Clustering
# Perform hierarchical clustering
dist_matrix = 1 - np.corrcoef(triviadata1['Category'].value_counts().values.reshape(1, -1).T)
Z = linkage(dist_matrix, method='ward')
n_clusters = 10
# Out:
# c:\Users\shyar\anaconda3\envs\dev\lib\site-packages\numpy\lib\function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\Users\shyar\anaconda3\envs\dev\lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# c:\Users\shyar\anaconda3\envs\dev\lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 4
#       1 # Another type of Clustering
#       2 # Perform hierarchical clustering
#       3 dist_matrix = 1 - np.corrcoef(triviadata1['Category'].value_counts().values.reshape(1, -1).T)
# ----> 4 Z = linkage(dist_matrix, method='ward')
#       5 n_clusters = 10
#
# File c:\Users\shyar\anaconda3\envs\dev\lib\site-packages\scipy\cluster\hierarchy.py:1030, in linkage(y, method, metric, optimal_ordering)
#    1027     raise ValueError("`y` must be 1 or 2 dimensional.")
#    1029 if not xp.all(xp.isfinite(y)):
# -> 1030     raise ValueError("The condensed distance matrix must contain only "
#    1031                      "finite values.")
#    1033 n = int(distance.num_obs_y(y))
#    1034 method_code = _LINKAGE_METHODS[method]
#
# ValueError: The condensed distance matrix must contain only finite values.

# %%
# Perform hierarchical clustering
clusters = fcluster(Z, n_clusters, criterion='maxclust')

# Create a mapping of original categories to new clusters
category_mapping = {i: c for i, c in enumerate(clusters)}

# Add cluster information to the original dataframe
triviadata1['cluster'] = triviadata1['category'].map(category_mapping)

# Count questions per category
question_counts = triviadata1['category'].value_counts()

# Select top 10 categories based on number of questions
top_categories = question_counts.nlargest(10).index.tolist()

# Create final dataframe with selected categories
final_df = triviadata1[triviadata1['Category'].isin(top_categories)]

# Create a new column 'selected_category' with the top category names
final_df['selected_category'] = final_df['category']

# Add the mapping to the dataframe
final_df['category_mapping'] = final_df['cluster'].map(lambda x: list(category_mapping.keys())[list(category_mapping.values()).index(x)])

print(final_df)
